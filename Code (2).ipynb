# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv ('Information.csv')
df
# Out:
#       REF_DATE               GEO           DGUID          Dairy distribution  \
# 0      1946-01            Canada  2016A000011124      Milk production, total
# 1      1946-01            Canada  2016A000011124              Fluid purposes
# 2      1946-02            Canada  2016A000011124      Milk production, total
# 3      1946-02            Canada  2016A000011124              Fluid purposes
# 4      1946-03            Canada  2016A000011124      Milk production, total
# ...        ...               ...             ...                         ...
# 25456  2023-04           Alberta     2016A000248              Fluid purposes
# 25457  2023-04           Alberta     2016A000248         Industrial purposes
# 25458  2023-04  British Columbia     2016A000259  Milk sold off farms, total
# 25459  2023-04  British Columbia     2016A000259              Fluid purposes
# 25460  2023-04  British Columbia     2016A000259         Industrial purposes
#
# ...

# %%
df['TERMINATED'].value_counts()
# Out:
# t    6357
# Name: TERMINATED, dtype: int64

# %%
df = df.drop(['DGUID','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','STATUS','SYMBOL','DECIMALS'],axis=1)

# %%
df
# Out:
#       REF_DATE               GEO          Dairy distribution   VECTOR  \
# 0      1946-01            Canada      Milk production, total  v382152
# 1      1946-01            Canada              Fluid purposes  v382156
# 2      1946-02            Canada      Milk production, total  v382152
# 3      1946-02            Canada              Fluid purposes  v382156
# 4      1946-03            Canada      Milk production, total  v382152
# ...        ...               ...                         ...      ...
# 25456  2023-04           Alberta              Fluid purposes  v382223
# 25457  2023-04           Alberta         Industrial purposes  v382224
# 25458  2023-04  British Columbia  Milk sold off farms, total  v382162
# 25459  2023-04  British Columbia              Fluid purposes  v382163
# 25460  2023-04  British Columbia         Industrial purposes  v382164
#
#        COORDINATE     VALUE TERMINATED
# 0             1.1  363058.0          t
# 1             1.5  159466.0        NaN
# ...

# %%
df['TERMINATED']=df['TERMINATED'].replace('t',1)
df['TERMINATED']=df['TERMINATED'].fillna(0)

# %%
df
# Out:
#       REF_DATE               GEO          Dairy distribution   VECTOR  \
# 0      1946-01            Canada      Milk production, total  v382152
# 1      1946-01            Canada              Fluid purposes  v382156
# 2      1946-02            Canada      Milk production, total  v382152
# 3      1946-02            Canada              Fluid purposes  v382156
# 4      1946-03            Canada      Milk production, total  v382152
# ...        ...               ...                         ...      ...
# 25456  2023-04           Alberta              Fluid purposes  v382223
# 25457  2023-04           Alberta         Industrial purposes  v382224
# 25458  2023-04  British Columbia  Milk sold off farms, total  v382162
# 25459  2023-04  British Columbia              Fluid purposes  v382163
# 25460  2023-04  British Columbia         Industrial purposes  v382164
#
#        COORDINATE     VALUE  TERMINATED
# 0             1.1  363058.0         1.0
# 1             1.5  159466.0         0.0
# ...

# %%
df['TERMINATED'] = df['TERMINATED'].astype(int)

# %%
df.isna().sum().sum()
# Out:
# 627

# %%
rows_with_na = df[df.isna().any(axis=1)]
rows_with_na
# Out:
#       REF_DATE                        GEO  Dairy distribution   VECTOR  \
# 18963  2008-07                     Canada  Delivered as cream  v382158
# 18967  2008-07  Newfoundland and Labrador  Delivered as cream  v382169
# 18971  2008-07       Prince Edward Island  Delivered as cream  v382176
# 18975  2008-07                Nova Scotia  Delivered as cream  v382183
# 18979  2008-07              New Brunswick  Delivered as cream  v382190
# ...        ...                        ...                 ...      ...
# 21451  2013-03                    Ontario  Delivered as cream  v382204
# 21455  2013-03                   Manitoba  Delivered as cream  v382211
# 21459  2013-03               Saskatchewan  Delivered as cream  v382218
# 21463  2013-03                    Alberta  Delivered as cream  v382225
# 21467  2013-03           British Columbia  Delivered as cream  v382165
#
#        COORDINATE  VALUE  TERMINATED
# 18963         1.7    NaN           1
# 18967         2.7    NaN           1
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#       REF_DATE               GEO          Dairy distribution   VECTOR  \
# 0      1946-01            Canada      Milk production, total  v382152
# 1      1946-01            Canada              Fluid purposes  v382156
# 2      1946-02            Canada      Milk production, total  v382152
# 3      1946-02            Canada              Fluid purposes  v382156
# 4      1946-03            Canada      Milk production, total  v382152
# ...        ...               ...                         ...      ...
# 25456  2023-04           Alberta              Fluid purposes  v382223
# 25457  2023-04           Alberta         Industrial purposes  v382224
# 25458  2023-04  British Columbia  Milk sold off farms, total  v382162
# 25459  2023-04  British Columbia              Fluid purposes  v382163
# 25460  2023-04  British Columbia         Industrial purposes  v382164
#
#        COORDINATE     VALUE  TERMINATED
# 0             1.1  363058.0           1
# 1             1.5  159466.0           0
# ...

# %%
df['VALUE'] = df['VALUE'].astype(int)
# Out:
# C:\Users\aanch\AppData\Local\Temp\ipykernel_43188\757599667.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALUE'] = df['VALUE'].astype(int)

# %%
df
# Out:
#       REF_DATE               GEO          Dairy distribution   VECTOR  \
# 0      1946-01            Canada      Milk production, total  v382152
# 1      1946-01            Canada              Fluid purposes  v382156
# 2      1946-02            Canada      Milk production, total  v382152
# 3      1946-02            Canada              Fluid purposes  v382156
# 4      1946-03            Canada      Milk production, total  v382152
# ...        ...               ...                         ...      ...
# 25456  2023-04           Alberta              Fluid purposes  v382223
# 25457  2023-04           Alberta         Industrial purposes  v382224
# 25458  2023-04  British Columbia  Milk sold off farms, total  v382162
# 25459  2023-04  British Columbia              Fluid purposes  v382163
# 25460  2023-04  British Columbia         Industrial purposes  v382164
#
#        COORDINATE   VALUE  TERMINATED
# 0             1.1  363058           1
# 1             1.5  159466           0
# ...

# %%
df['Dairy distribution'].value_counts()
# Out:
# Fluid purposes                6608
# Milk sold off farms, total    6248
# Industrial purposes           6248
# Delivered as cream            4290
# Milk production, total         720
# Farm home consumed             360
# Fed to livestock               360
# Name: Dairy distribution, dtype: int64

# %%
df['GEO'].value_counts()
# Out:
# Canada                       2922
# Prince Edward Island         2202
# Nova Scotia                  2202
# New Brunswick                2202
# Quebec                       2202
# Ontario                      2202
# Manitoba                     2202
# Saskatchewan                 2202
# Alberta                      2202
# British Columbia             2202
# Newfoundland and Labrador    2094
# Name: GEO, dtype: int64

# %%
df=df.drop('COORDINATE',axis=1)

# %%
df
# Out:
#       REF_DATE               GEO          Dairy distribution   VECTOR   VALUE  \
# 0      1946-01            Canada      Milk production, total  v382152  363058
# 1      1946-01            Canada              Fluid purposes  v382156  159466
# 2      1946-02            Canada      Milk production, total  v382152  347330
# 3      1946-02            Canada              Fluid purposes  v382156  150728
# 4      1946-03            Canada      Milk production, total  v382152  421165
# ...        ...               ...                         ...      ...     ...
# 25456  2023-04           Alberta              Fluid purposes  v382223   26422
# 25457  2023-04           Alberta         Industrial purposes  v382224   42609
# 25458  2023-04  British Columbia  Milk sold off farms, total  v382162   67739
# 25459  2023-04  British Columbia              Fluid purposes  v382163   26974
# 25460  2023-04  British Columbia         Industrial purposes  v382164   40765
#
#        TERMINATED
# ...

# %%
df= df.drop(df[df['VALUE'] == 0].index)

# %%
df
# Out:
#       REF_DATE               GEO          Dairy distribution   VECTOR   VALUE  \
# 0      1946-01            Canada      Milk production, total  v382152  363058
# 1      1946-01            Canada              Fluid purposes  v382156  159466
# 2      1946-02            Canada      Milk production, total  v382152  347330
# 3      1946-02            Canada              Fluid purposes  v382156  150728
# 4      1946-03            Canada      Milk production, total  v382152  421165
# ...        ...               ...                         ...      ...     ...
# 25456  2023-04           Alberta              Fluid purposes  v382223   26422
# 25457  2023-04           Alberta         Industrial purposes  v382224   42609
# 25458  2023-04  British Columbia  Milk sold off farms, total  v382162   67739
# 25459  2023-04  British Columbia              Fluid purposes  v382163   26974
# 25460  2023-04  British Columbia         Industrial purposes  v382164   40765
#
#        TERMINATED
# ...

# %%
df.duplicated().sum().sum()
# Out:
# 0

# %%
df.to_csv('Cleaned_df.csv')
